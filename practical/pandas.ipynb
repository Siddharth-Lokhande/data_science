# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddharth-Lokhande/data_science/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
arr=pd.Series([1,1,6,5,4],index=['a','b','c','d','e'])

# %%
arr
# Out:
# a    1
# b    1
# c    6
# d    5
# e    4
# dtype: int64

# %%
arr=pd.read_csv("data/iris.csv")

# %%
arr
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
arr.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
arr.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
arr.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
arr.insert(0, 'id', range(len(arr)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d5d74e1a726d> in <cell line: 0>()
# ----> 1 arr.insert(0, 'id', range(len(arr)))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#
# ValueError: cannot insert id, already exists

# %%
arr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# DATA SELECTION

# %%
arr["id"]
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 145    145
# 146    146
# 147    147
# 148    148
# 149    149
# Name: id, Length: 150, dtype: int64

# %%
arr[["id","sepal.length"]]
# Out:
#       id  sepal.length
# 0      0           5.1
# 1      1           4.9
# 2      2           4.7
# 3      3           4.6
# 4      4           5.0
# ..   ...           ...
# 145  145           6.7
# 146  146           6.3
# 147  147           6.5
# 148  148           6.2
# 149  149           5.9
#
# [150 rows x 2 columns]

# %%
arr.iloc[0]
# Out:
# id                   0
# sepal.length       5.1
# sepal.width        3.5
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 0, dtype: object

# %%
arr2=pd.read_csv("data/copy.csv")

# %%
arr2.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           NaN          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          NaN  Setosa
# 2           NaN          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           NaN          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
arr2.dropna()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 4             5.0          3.6           1.4          0.2     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [145 rows x 5 columns]

# %%
arr2.fillna(arr2.mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-74083bdd519c> in <cell line: 0>()
# ----> 1 arr2.fillna(arr2.mean(), inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
arr2.rename
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             NaN          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          NaN     Setosa
# 2             NaN          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           NaN          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
arr2['sepal.width']=arr2['sepal.width'].astype(str)

# %%
arr2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    object
#  1   sepal.width   150 non-null    object
#  2   petal.length  148 non-null    float64
#  3   petal.width   149 non-null    float64
#  4   variety       149 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 6.0+ KB

# %%
arr2.to_csv("data/dified.csv")

# %%
df1=pd.DataFrame({"name":["Harry","rohan","parth","soham"],"marks":[11,99,52,78],})

# %%
df1
# Out:
#     name  marks
# 0  Harry     11
# 1  rohan     99
# 2  parth     52
# 3  soham     78

# %%
df2=pd.DataFrame({"name":["diya","khyati","arya","krisha"],"marks":[15,86,46,63],})

# %%
df2
# Out:
#      name  marks
# 0    diya     15
# 1  khyati     86
# 2    arya     46
# 3  krisha     63

# %%
pd.concat([df1,df2])
# Out:
#      name  marks
# 0   Harry     11
# 1   rohan     99
# 2   parth     52
# 3   soham     78
# 0    diya     15
# 1  khyati     86
# 2    arya     46
# 3  krisha     63

# %%
df1=pd.DataFrame({"name":["sakshi","sneha","shraddha"],"marks":[31,41,51],})

# %%
df1
# Out:
#        name  marks
# 0    sakshi     31
# 1     sneha     41
# 2  shraddha     51

# %% [markdown]
# merging 2 dataframe

# %%
df2=pd.DataFrame({"name":["sakshi","sneha","shraddha"],"rollno":[3551,4441,6651],})

# %%
pd.merge(df1,df2,on="name")
# Out:
#        name  marks  rollno
# 0    sakshi     31    3551
# 1     sneha     41    4441
# 2  shraddha     51    6651
